# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
Cause_of_Death=pd.read_csv("Datasets/NCHS_-_Leading_Causes_of_Death__United_States.csv")
Cause_of_Death.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
Cause_of_Death["Cause Name"].unique()
Cause_of_Death["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'United States'],
#       dtype=object)

# %%
Cause_of_Death_Clean=Cause_of_Death.loc[Cause_of_Death["Cause Name"]!="All causes"]
Cause_of_Death_Clean=Cause_of_Death_Clean.loc[Cause_of_Death["State"]!="United States"]

# %%
Cause_of_Death_Clean["Cause Name"].unique()
Cause_of_Death_Clean["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
Grouped=Cause_of_Death_Clean.groupby(["Year","Cause Name"])

# %%
Grouped["Deaths"].sum()
Grouped["Age-adjusted Death Rate"].mean()
Sum=pd.DataFrame(Grouped["Deaths"].sum())
Average_Rate=pd.DataFrame(Grouped["Age-adjusted Death Rate"].mean())
Average_Rate = Average_Rate.reset_index()
Sum = Sum.reset_index()

# %%
Deaths_Alzheimer = Sum.loc[Sum["Cause Name"] == "Alzheimer's disease",:]
Deaths_CLRD = Sum.loc[Sum["Cause Name"] == "CLRD",:]
Deaths_Cancer = Sum.loc[Sum["Cause Name"] == "Cancer",:]
Deaths_Diabetes = Sum.loc[Sum["Cause Name"] == "Diabetes",:]
Deaths_HD = Sum.loc[Sum["Cause Name"] == "Heart disease",:]
Deaths_IP = Sum.loc[Sum["Cause Name"] == "Influenza and pneumonia",:]
Deaths_Kidney = Sum.loc[Sum["Cause Name"] == "Kidney disease",:]
Deaths_Stroke = Sum.loc[Sum["Cause Name"] == "Stroke",:]
Deaths_Suicide = Sum.loc[Sum["Cause Name"] == "Suicide",:]
Deaths_UI = Sum.loc[Sum["Cause Name"] == "Unintentional injuries",:]

plt.figure(figsize=(12,8))
plt.plot(Deaths_Alzheimer["Year"],Deaths_Alzheimer["Deaths"],label="Alzheimer's disease",linewidth=3)
plt.plot(Deaths_CLRD["Year"],Deaths_CLRD["Deaths"],label="CLRD",linewidth=3)
plt.plot(Deaths_Cancer["Year"],Deaths_Cancer["Deaths"],label="Cancer",linewidth=3, marker="o")
plt.plot(Deaths_Diabetes["Year"],Deaths_Diabetes["Deaths"],label="Diabetes",linewidth=3)
plt.plot(Deaths_HD["Year"],Deaths_HD["Deaths"],label="Heart disease",linewidth=3, marker="o")
plt.plot(Deaths_IP["Year"],Deaths_IP["Deaths"],label="Influenza and pnumonia",linewidth=3)
plt.plot(Deaths_Kidney["Year"],Deaths_Kidney["Deaths"],label="Kidney disease",linewidth=3)
plt.plot(Deaths_Stroke["Year"],Deaths_Stroke["Deaths"],label="Stroke",linewidth=3)
plt.plot(Deaths_Suicide["Year"],Deaths_Suicide["Deaths"],label="Suicide",linewidth=3)
plt.plot(Deaths_UI["Year"],Deaths_UI["Deaths"],label="Unintentional injuries",linewidth=3, marker="o")

plt.legend(loc="upper right")
plt.xticks(Deaths_Alzheimer["Year"])
plt.legend(loc="upper left",bbox_to_anchor=(1,1))

plt.title("Total Number of Death by Cause")
plt.xlabel("Year")
plt.ylabel("Total Number of Death in US")
plt.grid()

plt.tight_layout()
plt.savefig("..\Project-One\Q3_Image 1")
plt.show()

# %%
Rate_Alzheimer = Average_Rate.loc[Average_Rate["Cause Name"] == "Alzheimer's disease",:]
Rate_CLRD = Average_Rate.loc[Average_Rate["Cause Name"] == "CLRD",:]
Rate_Cancer = Average_Rate.loc[Average_Rate["Cause Name"] == "Cancer",:]
Rate_Diabetes = Average_Rate.loc[Average_Rate["Cause Name"] == "Diabetes",:]
Rate_HD = Average_Rate.loc[Average_Rate["Cause Name"] == "Heart disease",:]
Rate_IP = Average_Rate.loc[Average_Rate["Cause Name"] == "Influenza and pneumonia",:]
Rate_Kidney = Average_Rate.loc[Average_Rate["Cause Name"] == "Kidney disease",:]
Rate_Stroke = Average_Rate.loc[Average_Rate["Cause Name"] == "Stroke",:]
Rate_Suicide = Average_Rate.loc[Average_Rate["Cause Name"] == "Suicide",:]
Rate_UI = Average_Rate.loc[Average_Rate["Cause Name"] == "Unintentional injuries",:]


plt.figure(figsize=(12,8))
ax=plt.axes()
plt.xlim=(1999,2016,1)

plt.plot(Rate_Alzheimer["Year"],Rate_Alzheimer["Age-adjusted Death Rate"],label="Alzheimer's disease",linewidth=3)
plt.plot(Rate_CLRD["Year"],Rate_CLRD["Age-adjusted Death Rate"],label="CLRD",linewidth=3)
plt.plot(Rate_Cancer["Year"],Rate_Cancer["Age-adjusted Death Rate"],label="Cancer",linewidth=3,marker="o")
plt.plot(Rate_Diabetes["Year"],Rate_Diabetes["Age-adjusted Death Rate"],label="Diabetes",linewidth=3)
plt.plot(Rate_HD["Year"],Rate_HD["Age-adjusted Death Rate"],label="Heart disease",linewidth=3,marker="o")
plt.plot(Rate_IP["Year"],Rate_IP["Age-adjusted Death Rate"],label="Influenza and pnumonia",linewidth=3)
plt.plot(Rate_Kidney["Year"],Rate_Kidney["Age-adjusted Death Rate"],label="Kidney disease",linewidth=3)
plt.plot(Rate_Stroke["Year"],Rate_Stroke["Age-adjusted Death Rate"],label="Stroke",linewidth=3)
plt.plot(Rate_Suicide["Year"],Rate_Suicide["Age-adjusted Death Rate"],label="Suicide",linewidth=3)
plt.plot(Rate_UI["Year"],Rate_UI["Age-adjusted Death Rate"],label="Unintentional injuries",linewidth=3, marker="o")

plt.grid()

plt.legend(loc="upper right")
plt.xticks(Deaths_Alzheimer["Year"])
plt.legend(loc="upper left",bbox_to_anchor=(1,1))

plt.title("Death Rate by Cause")
plt.xlabel("Year")
plt.ylabel("Average Age-adjusted Death Rate in US")

plt.tight_layout()
plt.savefig("..\Project-One\Q3_Image 2")
plt.show()
